# %% [markdown]
# ## Session 4: Visualisation – Static & Interactive
#
# **Date:** 18/05/2026
# **Objective:** Create publication‑quality static visualisations (Matplotlib, Seaborn) and interactive charts (Plotly) to uncover patterns in gaming communities. No statistical hypothesis testing – focus solely on exploratory and explanatory visualisation.
#
# ---
#
# ### 4.1 Agenda for Session 4
#
# | Part | Activity | Tools | Questions |
# |------|----------|-------|-----------|
# | **M1** | Histogram of `log_member_count` + KDE | Matplotlib | 1 |
# | **M2** | Horizontal bar chart of mean engagement per genre | Matplotlib | 2 |
# | **M3** | Scatter plot with trendline coloured by `community_tier` | Matplotlib | 3 |
# | **M4** | Boxplot of `tournament_intensity` by `primary_platform` | Matplotlib | 4 |
# | **M5** | Dual‑axis plot: line + bars (first 50 communities) | Matplotlib | 5 |
# | **M6** | Violin plot of `avg_member_age` by region | Matplotlib | 6 |
# | **M7** | Stacked bar chart of community tiers per genre | Matplotlib | 7 |
# | **M8** | Error bar chart of coaching staff per tier | Matplotlib | 8 |
# | **M9** | Hexbin heatmap of member count vs engagement ratio | Matplotlib | 9 |
# | **M10** | 2×2 subplot dashboard | Matplotlib | 10 |
# | **S1** | Pairplot of key numeric columns (coloured by genre) | Seaborn | 1 |
# | **S2** | FacetGrid histograms of engagement ratio by region & tier | Seaborn | 2 |
# | **S3** | Jointplot with KDE and marginal histograms | Seaborn | 3 |
# | **S4** | Boxen plot of average member age by region | Seaborn | 4 |
# | **S5** | Correlation heatmap with mask | Seaborn | 5 |
# | **S6** | FacetGrid: violin + stripplot of tournament intensity by genre | Seaborn | 6 |
# | **S7** | Regression plot with confidence band (member count vs social presence) | Seaborn | 7 |
# | **S8** | Count plot of coaching percentage per genre (normalised) | Seaborn | 8 |
# | **P1** | Interactive bar chart of mean engagement per region (with error bars) | Plotly Express | 1 |
# | **P2** | Interactive scatter: size = social presence, colour = tier | Plotly Express | 2 |
# | **P3** | 3D scatter plot (member count, engagement, tournament intensity) | Plotly Graph Objects | 3 |
# | **P4** | Sunburst chart: region → genre → tier | Plotly Express | 4 |
# | **P5** | Interactive line chart of cumulative members for top 3 genres | Plotly Express | 5 |
# | **P6** | Box plot with all points and notch | Plotly Express | 6 |
# | **P7** | Histogram of log member count with marginal rug | Plotly Express | 7 |
# | **P8** | Density heatmap (member count vs active players) with marginals | Plotly Express | 8 |
# | **P9** | Bar chart of top 15 countries by total members (choropleth substitute) | Plotly Express | 9 |
# | **P10** | make_subplots dashboard: scatter + histogram | Plotly Graph Objects | 10 |
#
# ---
#
# ### 4.2 Expected Deliverables
#
# - [ ] All 10 Matplotlib visualisations saved as `.png` or `.svg` (optional but recommended).
# - [ ] All 8 Seaborn plots with clear interpretations.
# - [ ] All 10 Plotly interactive charts displayed in the notebook (saved as HTML if desired).
# - [ ] At least three markdown insights explaining what each chart reveals about gaming communities.
# - [ ] (Optional) Export interactive charts as standalone HTML files.
#
# ---
#
# ### 4.3 Tools & Libraries
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
# import numpy as np
# import pandas as pd

# %%
#importing essential libraries 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import pandas as pd

# %%
#loading the dataset
gaming_data = pd.read_csv('gaming_communities_enhanced.csv')

# %%
#Histogram of Log Member Count with KDE
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.histplot(
        data = gaming_data,
        x = 'log_member_count',
        bins=30,
        color='steelblue',
        edgecolor='white', 
        alpha=0.7,
        kde=True,
        line_kws={'linewidth':2},
        ax=ax
       )

kde_line = ax.lines[0]
kde_line.set_color('red')              
kde_line.set_label('KDE Trendline')    
ax.set_title('Distribution of Log Member Count', fontweight='bold', fontsize=14)
ax.set_xlabel('Log( Member Count + 1 )')
ax.set_ylabel('Frequency')
ax.legend()

plt.show()

# %%
#Horizontal Bar Chart of Mean Engagement Ratio by Genre
genre = gaming_data.groupby(['genre'])['engagement_ratio'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(12, 9), dpi=300)

bars = ax.barh(y=genre.index, width=genre.values,
        color='teal', edgecolor='black', linewidth=0.8,
        )
ax.bar_label(bars, padding=3, fontsize=9, fmt='%.3f')

ax.set_title("Average Engagement Ratio by Genre", fontweight='bold', fontsize=14)
ax.set_xlabel("Mean Engagement Ratio (active / members)")
ax.set_ylabel("Genre")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
#Scatter Plot of Member Count vs Active Players with Trendline
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)

tiers = gaming_data['community_tier'].astype('category')
tier_codes = tiers.cat.codes
tier_names = tiers.cat.categories

scatter = ax.scatter(x=gaming_data['member_count'], y=gaming_data['active_players'], c=tier_codes, alpha=0.6, 
                     s=30, cmap=plt.cm.Set2)

m, b = np.polyfit(gaming_data['member_count'], gaming_data['active_players'], 1)

x_trend = np.array([gaming_data['member_count'].min(), gaming_data['member_count'].max()])
y_trend = m * x_trend + b

ax.plot(
    x_trend, 
    y_trend, 
    color='black', 
    linestyle='--', 
    linewidth=1.5, 
    label='Trendline'
)

handles, _ = scatter.legend_elements()
ax.legend(handles, tier_names, title="Community Tier")

ax.set_title("Community Size vs Active Players by Tier")
ax.set_xlabel("Total Member Count")
ax.set_ylabel("Active Players")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.grid(True, linestyle=':', alpha=0.6, color='lightgrey')

plt.show()

# %%
#Boxplot of Tournament Intensity by Primary Platform
data = gaming_data.groupby('primary_platform')['tournament_intensity'].apply(list)
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
ax.boxplot(
    data,
    patch_artist=True,
    boxprops=dict(facecolor='lightblue', linewidth=1.5),
    tick_labels=data.index,
    flierprops=dict(marker='D', markerfacecolor='red', markersize=5),
    whiskerprops=dict(linewidth=1.2)
)

ax.set_title("Tournament Intensity by Primary Platform", fontweight='bold', fontsize=14)
ax.set_xlabel("Platform")
ax.set_ylabel("Tournaments Per 1,000 members")

plt.xticks(rotation=45)

plt.show()

# %%
#Dual‑Axis Plot: Community Age (line) vs Total Social Presence (bars)
data = gaming_data.sort_values('community_age').head(50)
x = range(len(data))
fig, ax = plt.subplots(figsize=(12, 5), dpi=300)
ax.plot(
    x,
    data['community_age'],
    color='blue',
    marker='o',
    linestyle='-',
    label='Community Age'
)
ax2 = ax.twinx()
ax2.bar(
    x,
    data['total_social_presence'],
    color='orange',
    alpha=0.6,
    label='Total Social Presence'
)

lines, labels1 = ax.get_legend_handles_labels()
bars, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + bars, labels1 + labels2, loc='upper left')

ax.set_title("Community Age vs Social Presence (First 50 Communities)", fontweight='bold')
ax.set_xlabel("Community Index (sorted by age)")
ax.set_ylabel("Community Age (years)")
ax2.set_ylabel("Total Social Presence (Discord + Reddit + Creators*1000)")

plt.show()

# %%
#Violin Plot of Average Member Age by Region
data = gaming_data.groupby('region')['avg_member_age'].apply(list)
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
vio = ax.violinplot(
    data,
    showmeans=False,
    showmedians=False
)
for col in vio['bodies']:
    col.set_facecolor('mediumseagreen')
    col.set_alpha(0.6)
    col.set_edgecolor('darkgreen')
    
ax.set_xticks(range(1, len(data) + 1))
ax.set_xticklabels(data.index)
plt.xticks(rotation=45)

global_median = gaming_data['avg_member_age'].median()
ax.axhline(
    y=global_median,
    linestyle='--',
    color='red',
    linewidth=1.5,
    zorder=3
)

ax.set_title("Distribution of Average Member Age by Region", fontweight='bold', fontsize=14)
ax.set_xlabel("Region")
ax.set_ylabel("Average Member Age (years)")

plt.show()

# %%
#Stacked Bar Chart: Community Tiers per Genre
tier_counts = pd.crosstab(gaming_data['genre'], gaming_data['community_tier'])
tiers_order = ['Amateur', 'Semi-Pro', 'Professional', 'Elite']
tier_counts = tier_counts.reindex(columns=tiers_order, fill_value=0)

fig, ax = fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
genres = tier_counts.index
colors = ['lightgreen','lightblue','salmon','gold']
bottom_vals = np.zeros(len(genres))

for i, tier in enumerate(tiers_order):
    ax.bar(
        genres,
        tier_counts[tier],
        bottom=bottom_vals,
        label=tier,
        color=colors[i],
        edgecolor='black',
        linewidth=0.5
    )
    bottom_vals += tier_counts[tier].values

ax.legend(title="Community Tier", bbox_to_anchor=(1.05, 1), loc='upper left')

ax.set_title("Composition of Community Tiers by Genre", fontweight='bold', fontsize=14)
ax.set_xlabel("Genre", fontsize=11)
ax.set_ylabel("Number of Communities", fontsize=11)

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
#Error Bar Chart: Mean Coaching Staff per Tier
data = gaming_data.groupby('community_tier')['coaching_staff'].agg(['mean', 'std', 'count'])
data['sem'] = data['std'] / np.sqrt(data['count'])
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
bars = ax.bar(
    data.index,
    data['mean'],
    yerr=data['sem'],
    capsize=5,
    color='steelblue', 
    edgecolor='black', 
    linewidth=0.8
)
ax.bar_label(bars, padding=3, fontsize=9, fmt='%.2f')
ax.set_title("Average Coaching Staff by Community Tier", fontsize=14, fontweight='bold')
ax.set_xlabel("Community Tier")
ax.set_ylabel("Mean Coaching Staff (number of coaches)")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
#Hexbin Heatmap: Member Count vs Engagement Ratio
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
hb = ax.hexbin(gaming_data['member_count'], gaming_data['engagement_ratio'], cmap='plasma', gridsize=40, xscale='log')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Number of Points')

ax.set_title("Density of Communities by Size and Engagement", fontsize=14, fontweight='bold')
ax.set_xlabel("Member Count")
ax.set_ylabel("Engagement Ratio (active/members)")

plt.show()

# %%
#2×2 Subplot Dashboard
fig, axes = plt.subplots(2, 2, figsize=(14, 11), dpi=300)

#top-left
axes[0][0].hist(
        gaming_data['log_member_count'],
        bins=25,
        color='coral',
        edgecolor='white', 
        alpha=0.7
       )
axes[0][0].set_title("Log Member Count Distribution", fontsize=12, pad=12, fontweight='bold')
axes[0][0].set_xlabel("Log of Member Count", labelpad=10)
axes[0][0].set_ylabel("Frequency", labelpad=10)

#top-right
data = gaming_data.groupby('country_of_origin')['member_count'].sum().nlargest(5)
bars = axes[0][1].barh(
    y=data.index,
    width=data,
    color='steelblue'
)
axes[0][1].tick_params(axis='x', rotation=45)
axes[0][1].tick_params(axis='y', rotation=45)
axes[0][1].set_title("Top 5 Countries by Total Members", fontsize=12, pad=12, fontweight='bold')
axes[0][1].set_xlabel("Total Member Count", labelpad=10)
axes[0][1].set_ylabel("Country of Origin", labelpad=10)

#bottom-left
coaching_cats = gaming_data['has_coaching'].astype('category')
coaching_codes = coaching_cats.cat.codes
coaching_names = coaching_cats.cat.categories

scatter_bl = axes[1][0].scatter(
    x=gaming_data['avg_member_age'],
    y=gaming_data['top_player_rank'],
    c=coaching_codes,
    cmap='bwr',
    alpha=0.7,
    s=30,
    edgecolor='white',
    linewidth=0.5
)

handles_bl, _ = scatter_bl.legend_elements()
axes[1][0].legend(handles_bl, coaching_names, title="Has Coaching")
axes[1][0].set_title("Member Age vs Player Rank (coaching flag)", fontsize=12, pad=12, fontweight='bold')
axes[1][0].set_xlabel("Average Member Age", labelpad=10)
axes[1][0].set_ylabel("Top Player Rank", labelpad=10)

#bottom right
data = gaming_data.groupby('community_tier')['tournament_intensity'].apply(list)
axes[1][1].boxplot(
    data,
    patch_artist=True,
    boxprops=dict(facecolor='lightblue', linewidth=1.5),
    tick_labels=data.index,
    flierprops=dict(marker='D', markerfacecolor='red', markersize=5),
    whiskerprops=dict(linewidth=1.2)
)
axes[1][1].set_title("Tournament Intensity by Community Tier", fontsize=12, pad=12, fontweight='bold')
axes[1][1].set_xlabel("Community Tier", labelpad=10)
axes[1][1].set_ylabel("Tournament Intensity", labelpad=10)

fig.suptitle("Community Insights Dashboard", fontsize=16, fontweight='bold', y=0.96)


plt.subplots_adjust(left=0.08, right=0.95, bottom=0.08, top=0.86, wspace=0.35, hspace=0.45)

plt.show()

# %%
#SEABORN section

# %%
#Pairplot of Key Numeric Columns by Genre
columns_to_plot = [
    'member_count', 
    'engagement_ratio', 
    'top_player_rank', 
    'avg_member_age', 
    'tournaments_hosted',
    'genre' 
]

numeric_data = gaming_data[columns_to_plot]
plt.rcParams['figure.dpi'] = 300
scatter = sns.pairplot(
    data=numeric_data, 
    hue='genre',  
    palette='Set2', 
    corner=True, 
    height=2.5,
    plot_kws={'edgecolor': 'white', 'linewidth': 0.4, 'alpha': 0.8}
)

scatter.fig.suptitle('Pairwise Relationships by Genre', y=1.02, fontweight='bold', fontsize=14)

plt.show()

# %%
#FacetGrid Histograms of Engagement Ratio by Region and Tier
facet = sns.FacetGrid(gaming_data, row='community_tier', col='region', height=3, aspect=1.2)
plt.rcParams['figure.dpi'] = 300
facet.map(sns.histplot, 'engagement_ratio', bins=20, kde=False, color='steelblue', edgecolor='white')
facet.set_axis_labels('Engagement Ratio', 'Count')
facet.set_titles(col_template='{col_name}', row_template='{row_name}')

facet.fig.suptitle('Distribution of Engagement Ratio by Region and Tier', y=1.05, fontweight='bold', fontsize=14)

plt.show()

# %%
#Jointplot with KDE and Marginal Histograms (Coloured by Platform)
g = sns.jointplot(
    gaming_data,
    x='member_count',
    y='active_players'
)
g.plot_joint(
    sns.kdeplot,
    data=gaming_data,
    hue='primary_platform',
    fill=True,
    alpha=0.5,
    palette='Set2'
)
sns.histplot(
    data=gaming_data,
    x='member_count',
    bins=20,
    color='grey',
    edgecolor='white',
    ax=g.ax_marg_x
)
sns.histplot(
    data=gaming_data,
    x='active_players',
    bins=20,
    color='grey',
    edgecolor='white',
    ax=g.ax_marg_y
)

g.fig.suptitle(
    "Member Count vs Active Players by Platform", 
    fontweight='bold', 
    fontsize=14, 
    y=1.03  
)
# Out:
# Text(0.5, 1.03, 'Member Count vs Active Players by Platform')

# %%
#Boxen Plot (Letter‑Value Plot) of Average Member Age by Region
order = gaming_data.groupby('region')['avg_member_age'].median().sort_values().index
sns.boxenplot(
    data=gaming_data,
    x='region',
    y='avg_member_age',
    hue='region',
    order=order,
    palette='Blues',
    legend=False
)
plt.xticks(rotation=45)
plt.suptitle(
    "Distribution of Average Member Age by Region (Boxen Plot)", 
    fontweight='bold', 
    fontsize=14, 
    y=1.03  
)
plt.ylabel('Average member age (years)')
# Out:
# Text(0, 0.5, 'Average member age (years)')

# %%
#Correlation Heatmap with Mask
numeric_cols = [
    'member_count', 'active_players', 'tournaments_hosted', 
    'top_player_rank', 'engagement_ratio', 'community_age', 
    'total_social_presence'
]
corr_matrix = gaming_data[numeric_cols].corr()

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

fig, ax = plt.subplots(figsize=(10, 8), dpi=300)

sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    square=True,
    linewidths=0.5,
    ax=ax
)

ax.set_title('Correlation Matrix of Community Metrics', fontweight='bold', fontsize=14, pad=20)

plt.show()

# %%
#FacetGrid: Violin + Stripplot of Tournament Intensity by Genre

genre_counts = gaming_data['genre'].value_counts()
valid_genres = genre_counts[genre_counts >= 20].index
filtered_data = gaming_data[gaming_data['genre'].isin(valid_genres)]

g = sns.FacetGrid(
    data=filtered_data, 
    col='genre', 
    col_wrap=4,       
    height=4, 
    aspect=0.8, 
    sharey=True
)


g.map(
    sns.violinplot, 
    'tournament_intensity', 
    inner=None, 
    color='lightblue'
)

g.map(
    sns.stripplot, 
    'tournament_intensity', 
    color='black', 
    size=2, 
    alpha=0.5, 
    jitter=True
)

g.set_axis_labels('Tournament Intensity', '')
g.set_titles(col_template="{col_name}")

g.fig.suptitle(
    "Tournament Intensity Distribution by Genre", 
    fontweight='bold', 
    fontsize=14, 
    y=1.05
)

plt.show()
# Out:
# C:\Users\Faizan Toheed\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\Faizan Toheed\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#Regression Plot with Confidence Band
g = sns.lmplot(
    data=gaming_data,
    x='member_count',
    y='total_social_presence',
    hue='has_coaching',
    logx=True,        
    ci=95,            
    palette={True: 'orange', False: 'steelblue'},
    scatter_kws={'alpha': 0.6, 's': 30},
    height=6,
    aspect=1.5        
)

g.fig.suptitle(
    'Member Count vs Social Presence (log scale, with coaching flag)', 
    fontweight='bold', 
    fontsize=14, 
    y=1.05
)

plt.show()

# %%
# Count plot of coaching percentage per genre (normalised)
g = sns.catplot(
    data=gaming_data, 
    x='genre', 
    hue='has_coaching', 
    kind='count', 
    stat='percent', 
    dodge=False,      
    height=5, 
    aspect=1.5,
    palette='Set2'    
)

plt.xticks(rotation=45, ha='right')

g.fig.suptitle(
    'Coaching Availability by Genre (Percent of Communities)', 
    fontweight='bold', 
    fontsize=14, 
    y=1.05
)

g.set_axis_labels('Genre', 'Percentage')

plt.show()

# %%
#Plotly

# %%
#Interactive Bar Chart: Mean Engagement Ratio by Region with Error Bars
data = gaming_data.groupby('region', as_index=False)['engagement_ratio'].agg(['mean', 'std'])

fig = px.bar(
    data, 
    x='region',
    y='mean',
    error_y='std',
    color='region',
    title='Average Engagement Ratio by Region (with std dev)',
    labels={
        'region': 'Region',
        'mean': 'Mean Engagement Ratio'
    },
    hover_data={
        'region':True,
        'mean':':.3f',
        'std':':.3f'
    }
)

fig.update_traces(
    hovertemplate="<b>Region:</b> %{x}<br><b>Mean:</b> %{y:.3f}<br><b>Error Margin (±):</b> %{error_y.array:.3f}<extra></extra>"
)
fig.write_html("region_engagement_analysis.html")
fig.show()

# %%
#Interactive Scatter Plot: Member Count vs Active Players with Size and Colour
fig = px.scatter(
    gaming_data,
    x='member_count',
    y='active_players',
    log_x=True,
    log_y=True,
    size='total_social_presence',
    size_max=20,
    color='community_tier',
    title='Community Size vs Active Players (bubbles sized by social presence)',
    labels={
        'member_count':'Member Count',
        'active_players':'Active Players'
    },
    hover_data={
        'region':True,
        'genre':True,
        'member_count':':,',
        'active_players':':,',
        'total_social_presence': ':.0f',
        'engagement_ratio': ':.2f'
    }
)
fig.write_html("scatter_social_presence.html")
fig.show()

# %%
# 3D Scatter Plot: Member Count, Engagement Ratio, and Tournament Intensity
fig = go.Figure(
    data=[go.Scatter3d(
        x=gaming_data['member_count'],
        y=gaming_data['engagement_ratio'],
        z=gaming_data['tournament_intensity'],
        mode='markers',
        marker=dict(
            size=4,
            opacity=0.7,
            color=gaming_data['region'].astype('category').cat.codes,
            colorscale='Viridis'
        )
    )]
)
fig.update_layout(
    title='3D Community Metrics Dashboard',
    scene=dict(
        xaxis=dict(title='Member Count', type='log'), # Fixed log_x here
        yaxis=dict(title='Engagement Ratio'),
        zaxis=dict(title='Tournament Intensity')
    )
)
fig.write_html("3d_scatter.html")

fig.show()

# %%
#Sunburst Chart: Hierarchy by Region → Genre → Community Tier
fig = px.sunburst(
    gaming_data,
    path=['region', 'genre', 'community_tier'],
    values='member_count', 
    color_continuous_scale='Viridis',
    title='Hierarchical Structure of Communities (Region → Genre → Tier)',
    hover_data={
        'region':True,
        'genre':True,
        'community_tier':True,
        'member_count': ':,',
        'active_players': ':,'
    }
)

fig.update_traces(
    hovertemplate="""
    <b>%{label}</b><br>
    Members: %{value:,}<br>
    % of Share in Parent: %{percentParent:.1%}<br>
    % of Total Global Share: %{percentRoot:.1%}<br>
    <extra></extra>
    """
)

fig.write_html("sunburst_region_genre_tier.html")

fig.show()

# %%
#Interactive Line Chart: Cumulative Members Over Time for Top 3 Genres
top_3_genres = gaming_data.groupby('genre')['member_count'].sum().nlargest(3).index.tolist()
filtered_growth = gaming_data[gaming_data['genre'].isin(top_3_genres)].copy()
filtered_growth = filtered_growth.sort_values(by='year_founded', ascending=True)
filtered_growth['cumulative_members'] = filtered_growth.groupby('genre')['member_count'].cumsum()

fig = px.line(
    filtered_growth,
    x='year_founded',
    y='cumulative_members',
    color='genre',
    markers=True,
    title='Cumulative Member Growth of Top 3 Genres Over Years',
    labels={
        'year_founded':'Year Founded',
        'cumulative_members':'Cumulative Total members'
    }
)
fig.update_layout(
    hovermode='x unified',
    dragmode='pan'  
)

fig.write_html("cumulative_growth_top3_genres.html")

fig.show()

# %%
#Interactive Box Plot: Tournament Intensity by Community Tier (with All Points)
fig = px.box(
    gaming_data,
    x='community_tier',
    y='tournament_intensity',
    color='community_tier',
    points='all',
    notched=True,
    title='Tournament Intensity Distribution by Tier (All Points Shown)',
    labels={
        'community_tier': 'Community Tier',
        'tournament_intensity': 'Tournaments per 1,000 Members'  
    }
)
fig.write_html("box_tournament_intensity_by_tier.html")

fig.show()

# %%
#Histogram of Log Member Count with Marginal Rug Plot
fig = px.histogram(
    gaming_data,
    x='log_member_count',
    nbins=30,
    marginal='rug',
    color='primary_platform',
    opacity=0.6,
    barmode='overlay',
    title='Distribution of Log Member Count by Primary Platform',
    labels={
        'log_member_count':'Log(Member count + 1)',
        'count':'Count'
    }
)
fig.write_html("hist_log_member_count_by_platform.html")

fig.show()

# %%
gaming_data['log_member_count_heatmap'] = np.log10(gaming_data['member_count'] + 1)
gaming_data['log_active_players_heatmap'] = np.log10(gaming_data['active_players'] + 1)

fig = px.density_heatmap(
    gaming_data,
    x='log_member_count_heatmap',
    y='log_active_players_heatmap',
    marginal_x='histogram',
    marginal_y='histogram',
    title='2D Density of Communities: Member Count vs Active Players',
    labels={
        'log_member_count_heatmap': 'Log10(Member Count)',
        'log_active_players_heatmap': 'Log10(Active Players)'
    }
)

fig.update_layout(
    coloraxis_colorscale='Viridis',
    xaxis=dict(
        tickvals=[0, 1, 2, 3, 4, 5, 6],
        ticktext=['1', '10', '100', '1k', '10k', '100k', '1M']
    ),
    yaxis=dict(
        tickvals=[0, 1, 2, 3, 4, 5, 6],
        ticktext=['1', '10', '100', '1k', '10k', '100k', '1M']
    )
)

fig.write_html("density_heatmap_member_active.html")

fig.show()

# %%
#Bar Chart of Top 15 Countries by Total Members
data = gaming_data.groupby('country_of_origin')['member_count'].sum().nlargest(15)
fig = px.bar(
    data,
    x=data.values,
    y=data.index,
    color=data.values,
    orientation='h',
    color_continuous_scale='Viridis',
    title='Top 15 Countries by Total Members',
    labels={
        'x': 'Total Member Count',
        'y': 'Country of Origin'
    }
)
fig.update_layout(yaxis={'categoryorder': 'total ascending'})
fig.write_html("top15_countries_bar.html")

fig.show()

# %%
# Create a 1x2 Subplot Dashboard
fig = make_subplots(
    rows=1, 
    cols=2, 
    subplot_titles=(
        'Community Size vs Engagement', 
        'Member Age Distribution'
    ),
    horizontal_spacing=0.12
)

colors = {True: '#FF9F43', False: '#54A0FF'}

for coaching_status in [True, False]:
    df_subset = gaming_data[gaming_data['has_coaching'] == coaching_status]
    label_text = "Coaching Available" if coaching_status else "No Coaching"
    
    fig.add_trace(
        go.Scatter(
            x=df_subset['member_count'],
            y=df_subset['engagement_ratio'],
            mode='markers',
            name=label_text,
            marker=dict(color=colors[coaching_status], size=7, opacity=0.7),
            hovertemplate="<b>" + label_text + "</b><br>Members: %{x:,}<br>Engagement: %{y:.3f}<extra></extra>"
        ),
        row=1, col=1
    )
    
    fig.add_trace(
        go.Histogram(
            x=df_subset['avg_member_age'],
            nbinsx=25,
            name=label_text,
            marker=dict(color=colors[coaching_status], opacity=0.6),
            showlegend=False,  
            hovertemplate="<b>" + label_text + "</b><br>Age Group: %{x:.1f} yrs<br>Count: %{y}<extra></extra>"
        ),
        row=1, col=2
    )

fig.update_layout(
    title_text='Community Size vs Engagement (left) and Age Distribution (right)',
    barmode='overlay',     
    xaxis1=dict(title='Member Count', type='log'), 
    yaxis1=dict(title='Engagement Ratio'),
    xaxis2=dict(title='Average Member Age (Years)'),
    yaxis2=dict(title='Count'),
    legend_title_text='Coaching Status'
)

fig.write_html("dashboard_scatter_histogram.html")

fig.show()
